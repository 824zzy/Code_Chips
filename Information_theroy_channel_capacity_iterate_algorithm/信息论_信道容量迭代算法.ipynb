# %% [markdown]
# # 基于colab平台的信息论-信道容量迭代算算法（python实现版）
# ## Copyright 2018 The BUPT Zhengyuan Zhu.
#
# Licensed under the Apache License, Version 2.0 (the "License").
# <table class="tfo-notebook-buttons" align="center"><td>
#
#
# <td>
# <a target="_blank"  href="https://github.com/824zzy/Code_Chips/blob/master/DataMining_text_classification.ipynb"><img width=32px src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View all sources on GitHub</a></td>
# </table>
#
# ### Affilication: BUPT
# ### Author:824zzy(计算机学院-2018140455-朱正源)
#
# ### References
# - 《信息论基础（第二版）》
# - [信道容量](https://zh.wikipedia.org/wiki/%E4%BF%A1%E9%81%93%E5%AE%B9%E9%87%8F)

# %% [markdown]
# - 算法原理
# - 算法适用条件
# - 求解结果

# %% [markdown]
# # 信道容量的迭代算法
# 书中第六章介绍的离散信道容量的计算智能处理某些特殊情况，因此本实验针对任意的离散信道的转移概率分布，使用迭代算法进行计算。

# %% [markdown]
# ## 符号定义
# - $r$: 输入符号集大小
# - $s$:输出符号集大小
# - $\epsilon$: 很小的正数
# - $p_i$:概率分布
# - $C$:信道容量
# - $q_{ji}=P_{X|Y}(a_i|b_j)$:反条件概率
# - $I(x;y)$: $p_i$和$q_{ji}$的互信息
# - $u$:中间变量，表示$\sum_ip_i\alpha_i$

# %% [markdown]
# ## 信道容量的意义
# 在信息论中，信道容量（Channel capacity，又译通道容量）是指在一个信道中能够可靠地传送信息时可达速率的最小上界。所谓可靠传输指的是可以以任意小的错误率传递信息。根据有噪信道编码定理，信道容量是可以误差概率任意小地达到的给定信道的极限信息率。信道容量的单位为比特每秒、奈特每秒等等。
#
# 香农在第二次世界大战期间发展出信息论，为信道容量提了定义，并且提供了计算信道容量的数学模型。香农指出，信道容量是信道的输入与输出的互信息量的最大值，而相应的输入分布称为最佳输入分布。

# %% [markdown]
# ## 算法原理
# 1. 在约束条件$p_i$通过迭代计算使$I(x;y)=C(n, n)$收敛于信道容量
# 2. 当信道固定时，把$I(X;Y)$看成$p_i$和$q_{ij}$的函数，进行信道容量计算的迭代。

# %% [markdown]
# ## 算法适用条件
# 1. 离散信道的容量计算
# 2. 不适用于计算有约束信道的容量

# %% [markdown]
# ## 算法流程图
# ![](https://github.com/824zzy/Code_Chips/blob/master/Information_theroy_channel_capacity_iterate_algorithm/%E4%BF%A1%E9%81%93%E5%AE%B9%E9%87%8F%E8%BF%AD%E4%BB%A3%E7%AE%97%E6%B3%95%E6%B5%81%E7%A8%8B%E5%9B%BE.png?raw=true)

# %% [markdown]
# ## 算法实现（Python版本）

# %% [markdown]
# ### 导入需要的库

# %%
import numpy as np

# %% [markdown]
# ### 设置参数

# %%
# 很小的正数
e = 1e-7

# %% [markdown]
# ### 设置输入概率转移矩阵

# %%
p_1 = np.array([[0.98, 0.02],
                [0.05, 0.95]])

p_2 = np.array([[0.6, 0.4],
                [0.01, 0.99]])

p_3 = np.array([[0.8, 0.15, 0.05],
                [0.05, 0.15, 0.8]])

# p_4 = np.array([[0.99, 0.01, 0.0000001],
#                 [0.005, 0.99, 0.0049999],
#                 [0.0000001 , 0.01, 0.99]])
p_4 = np.array([[0.99, 0.01, np.finfo(float).eps],
                [0.005, 0.99, 0.005],
                [np.finfo(float).eps , 0.01, 0.99]])

# %% [markdown]
# ### 算法主体

# %%
def initiate_prob_distrib(p):
  p_x = np.transpose(np.ones((1, p.shape[0])) / p.shape[0])
  print("初始化概率分布为:\n", p_x)
  
  return p_x

p_x = initiate_prob_distrib(p_4)

def iteration(p_i, p_ij, k):
  q_j = np.sum(p_i * p_ij, axis=0)
  print("第 "+str(k)+" 次迭代的q_j为:\n", q_j)
  
  alpha_i = np.exp(np.sum(p_ij * np.log(p_ij / q_j), axis=1))
  alpha_i = np.expand_dims(alpha_i, axis=0)
  print("第 "+str(k)+" 次迭代的alpha_i为:\n", alpha_i)
  
  u = np.matmul(alpha_i, p_i)[0]
  print("第 "+str(k)+" 次迭代的u为:\n", u)
  
  I_L = np.log2(u)[0]
  print("第 "+str(k)+" 次迭代的I_L为:\n", I_L)
  
  I_U = np.log2(np.amax(alpha_i))
  print("第 "+str(k)+" 次迭代的I_U为:\n", I_U)

  if I_U - I_L < e:
    print("输出信道容量的值为:\n ", I_L)
    print("达到容量时的输入概率为:\n ", p_i)
    return True, I_L, p_i
  else:
    p_i = p_i * np.transpose(alpha_i) / u[0]
    print("第"+str(k)+"次更新后的概率分布为:\n", p_i)
    return False, _, p_i
    
flag, I_L, p_i = iteration(p_x, p_4, 1)
# Out:
# 初始化概率分布为:
#  [[0.33333333]
#  [0.33333333]
#  [0.33333333]]
# 第 1 次迭代的q_j为:
#  [0.33166667 0.33666667 0.33166667]
# 第 1 次迭代的alpha_i为:
#  [[2.85044085 2.78954522 2.85044085]]
# 第 1 次迭代的u为:
#  [2.83014231]
# 第 1 次迭代的I_L为:
#  1.5008745987390466
# 第 1 次迭代的I_U为:
#  1.511185065434228
# 第1次更新后的概率分布为:
#  [[0.33572409]
#  [0.32855182]
#  [0.33572409]]

# %% [markdown]
# ### 迭代求解

# %%
ans_dict = dict()
for p in (p_1, p_2, p_3, p_4):
  flag = False
  p_x = initiate_prob_distrib(p)
  k = 1
  while not flag:
    flag, ans, tmp_p = iteration(p_x, p, k)
    if not flag:
      p_x = tmp_p
      k = k + 1
    else:
      ans_dict[ans] = tmp_p
      
    print("-----" * 10)
  print("*****" * 20)
# Out:
# 初始化概率分布为:
#  [[0.5]
#  [0.5]]
# 第 1 次迭代的q_j为:
#  [0.515 0.485]
# 第 1 次迭代的alpha_i为:
#  [[1.76252885 1.68554718]]
# 第 1 次迭代的u为:
#  [1.72403801]
# 第 1 次迭代的I_L为:
#  0.7857915848501995
# 第 1 次迭代的I_U为:
#  0.8176468737496073
# 第1次更新后的概率分布为:
#  [[0.51116299]
#  [0.48883701]]
# --------------------------------------------------
# 第 2 次迭代的q_j为:
#  [0.52538158 0.47461842]
# 第 2 次迭代的alpha_i为:
#  [[1.72913904 1.71883751]]
# 第 2 次迭代的u为:
#  [1.72410327]
# 第 2 次迭代的I_L为:
#  0.7858461941715016
# 第 2 次迭代的I_U为:
#  0.790053880984547
# 第2次更新后的概率分布为:
#  [[0.512656]
#  [0.487344]]
# --------------------------------------------------
# 第 3 次迭代的q_j为:
#  [0.52677008 0.47322992]
# 第 3 次迭代的alpha_i为:
#  [[1.72477336 1.72340077]]
# 第 3 次迭代的u为:
#  [1.72410443]
# 第 3 次迭代的I_L为:
#  0.7858471659236256
# 第 3 次迭代的I_U为:
#  0.7864067985148375
# 第3次更新后的概率分布为:
#  [[0.5128549]
#  [0.4871451]]
# --------------------------------------------------
# 第 4 次迭代的q_j为:
#  [0.52695506 0.47304494]
# 第 4 次迭代的alpha_i为:
#  [[1.72419349 1.72401072]]
# 第 4 次迭代的u为:
#  [1.72410446]
# 第 4 次迭代的I_L为:
#  0.7858471831597305
# 第 4 次迭代的I_U为:
#  0.7859216870741439
# 第4次更新后的概率分布为:
#  [[0.51288138]
#  [0.48711862]]
# --------------------------------------------------
# 第 5 次迭代的q_j为:
#  [0.52697969 0.47302031]
# 第 5 次迭代的alpha_i为:
#  [[1.72411631 1.72409197]]
# 第 5 次迭代的u为:
#  [1.72410446]
# 第 5 次迭代的I_L为:
#  0.7858471834653258
# 第 5 次迭代的I_U为:
#  0.7858571034488149
# 第5次更新后的概率分布为:
#  [[0.51288491]
#  [0.48711509]]
# --------------------------------------------------
# 第 6 次迭代的q_j为:
#  [0.52698297 0.47301703]
# 第 6 次迭代的alpha_i为:
#  [[1.72410603 1.72410279]]
# 第 6 次迭代的u为:
#  [1.72410446]
# 第 6 次迭代的I_L为:
#  0.7858471834707437
# 第 6 次迭代的I_U为:
#  0.7858485043108221
# 第6次更新后的概率分布为:
#  [[0.51288538]
#  [0.48711462]]
# --------------------------------------------------
# 第 7 次迭代的q_j为:
#  [0.5269834 0.4730166]
# 第 7 次迭代的alpha_i为:
#  [[1.72410467 1.72410423]]
# 第 7 次迭代的u为:
#  [1.72410446]
# 第 7 次迭代的I_L为:
#  0.7858471834708396
# 第 7 次迭代的I_U为:
#  0.7858473593403347
# 第7次更新后的概率分布为:
#  [[0.51288544]
#  [0.48711456]]
# --------------------------------------------------
# 第 8 次迭代的q_j为:
#  [0.52698346 0.47301654]
# 第 8 次迭代的alpha_i为:
#  [[1.72410448 1.72410443]]
# 第 8 次迭代的u为:
#  [1.72410446]
# 第 8 次迭代的I_L为:
#  0.7858471834708413
# 第 8 次迭代的I_U为:
#  0.7858472068878237
# 输出信道容量的值为:
#   0.7858471834708413
# 达到容量时的输入概率为:
#   [[0.51288544]
#  [0.48711456]]
# --------------------------------------------------
# ****************************************************************************************************
# 初始化概率分布为:
#  [[0.5]
#  [0.5]]
# 第 1 次迭代的q_j为:
#  [0.305 0.695]
# 第 1 次迭代的alpha_i为:
#  [[1.20320858 1.37173711]]
# 第 1 次迭代的u为:
#  [1.28747285]
# 第 1 次迭代的I_L为:
#  0.36454200516440166
# 第 1 次迭代的I_U为:
#  0.45600401850691225
# 第1次更新后的概率分布为:
#  [[0.46727532]
#  [0.53272468]]
# --------------------------------------------------
# 第 2 次迭代的q_j为:
#  [0.28569244 0.71430756]
# 第 2 次迭代的alpha_i为:
#  [[1.23771712 1.3358985 ]]
# 第 2 次迭代的u为:
#  [1.29002076]
# 第 2 次迭代的I_L为:
#  0.3673942866779384
# 第 2 次迭代的I_U为:
#  0.41781039628633504
# 第2次更新后的概率分布为:
#  [[0.44832974]
#  [0.55167026]]
# --------------------------------------------------
# 第 3 次迭代的q_j为:
#  [0.27451454 0.72548546]
# 第 3 次迭代的alpha_i为:
#  [[1.2598651  1.31604508]]
# 第 3 次迭代的u为:
#  [1.29085793]
# 第 3 次迭代的I_L为:
#  0.36833022445510555
# 第 3 次迭代的I_U为:
#  0.39620890842031165
# 第3次更新后的概率分布为:
#  [[0.43756557]
#  [0.56243443]]
# --------------------------------------------------
# 第 4 次迭代的q_j为:
#  [0.26816369 0.73183631]
# 第 4 次迭代的alpha_i为:
#  [[1.2732368  1.30504362]]
# 第 4 次迭代的u为:
#  [1.29112605]
# 第 4 次迭代的I_L为:
#  0.36862985713188334
# 第 4 次迭代的I_U为:
#  0.38409803118416963
# 第4次更新后的概率分布为:
#  [[0.43150287]
#  [0.56849713]]
# --------------------------------------------------
# 第 5 次迭代的q_j为:
#  [0.26458669 0.73541331]
# 第 5 次迭代的alpha_i为:
#  [[1.28103606 1.29893372]]
# 第 5 次迭代的u为:
#  [1.29121083]
# 第 5 次迭代的I_L为:
#  0.3687245861695091
# 第 5 次迭代的I_U为:
#  0.3773278211780116
# 第5次更新后的概率分布为:
#  [[0.42810261]
#  [0.57189739]]
# --------------------------------------------------
# 第 6 次迭代的q_j为:
#  [0.26258054 0.73741946]
# 第 6 次迭代的alpha_i为:
#  [[1.28549794 1.29553387]]
# 第 6 次迭代的u为:
#  [1.29123746]
# 第 6 次迭代的I_L为:
#  0.36875433852718664
# 第 6 次迭代的I_U为:
#  0.3735467296576528
# 第6次更新后的概率分布为:
#  [[0.42619971]
#  [0.57380029]]
# --------------------------------------------------
# 第 7 次迭代的q_j为:
#  [0.26145783 0.73854217]
# 第 7 次迭代的alpha_i为:
#  [[1.28802306 1.29363954]]
# 第 7 次迭代的u为:
#  [1.29124579]
# 第 7 次迭代的I_L为:
#  0.36876365018381285
# 第 7 次迭代的I_U为:
#  0.3714356753225536
# 第7次更新后的概率分布为:
#  [[0.42513598]
#  [0.57486402]]
# --------------------------------------------------
# 第 8 次迭代的q_j为:
#  [0.26083023 0.73916977]
# 第 8 次迭代的alpha_i为:
#  [[1.28944349 1.2925832 ]]
# 第 8 次迭代的u为:
#  [1.2912484]
# 第 8 次迭代的I_L为:
#  0.3687665588688373
# 第 8 次迭代的I_U为:
#  0.37025715100397105
# 第8次更新后的概率分布为:
#  [[0.42454173]
#  [0.57545827]]
# --------------------------------------------------
# 第 9 次迭代的q_j为:
#  [0.26047962 0.73952038]
# 第 9 次迭代的alpha_i为:
#  [[1.29023981 1.29199389]]
# 第 9 次迭代的u为:
#  [1.29124921]
# 第 9 次迭代的I_L为:
#  0.3687674664931587
# 第 9 次迭代的I_U为:
#  0.36959924558036555
# 第9次更新后的概率分布为:
#  [[0.42420985]
#  [0.57579015]]
# --------------------------------------------------
# 第 10 次迭代的q_j为:
#  [0.26028381 0.73971619]
# 第 10 次迭代的alpha_i为:
#  [[1.29068541 1.29166503]]
# 第 10 次迭代的u为:
#  [1.29124946]
# 第 10 次迭代的I_L为:
#  0.36876774954146935
# 第 10 次迭代的I_U为:
#  0.36923197720162637
# 第10次更新后的概率分布为:
#  [[0.42402455]
#  [0.57597545]]
# --------------------------------------------------
# 第 11 次迭代的q_j为:
#  [0.26017448 0.73982552]
# 第 11 次迭代的alpha_i为:
#  [[1.29093449 1.29148148]]
# 第 11 次迭代的u为:
#  [1.29124954]
# 第 11 次迭代的I_L为:
#  0.3687678377830511
# 第 11 次迭代的I_U为:
#  0.36902695453819456
# 第11次更新后的概率分布为:
#  [[0.42392109]
#  [0.57607891]]
# --------------------------------------------------
# 第 12 次迭代的q_j为:
#  [0.26011344 0.73988656]
# 第 12 次迭代的alpha_i为:
#  [[1.29107364 1.29137903]]
# 第 12 次迭代的u为:
#  [1.29124957]
# 第 12 次迭代的I_L为:
#  0.3687678652877619
# 第 12 次迭代的I_U为:
#  0.3689125035527101
# 第12次更新后的概率分布为:
#  [[0.42386333]
#  [0.57613667]]
# --------------------------------------------------
# 第 13 次迭代的q_j为:
#  [0.26007937 0.73992063]
# 第 13 次迭代的alpha_i为:
#  [[1.29115135 1.29132184]]
# 第 13 次迭代的u为:
#  [1.29124957]
# 第 13 次迭代的I_L为:
#  0.3687678738600523
# 第 13 次迭代的I_U为:
#  0.3688486129590487
# 第13次更新后的概率分布为:
#  [[0.42383109]
#  [0.57616891]]
# --------------------------------------------------
# 第 14 次迭代的q_j为:
#  [0.26006034 0.73993966]
# 第 14 次迭代的alpha_i为:
#  [[1.29119474 1.29128992]]
# 第 14 次迭代的u为:
#  [1.29124958]
# 第 14 次迭代的I_L为:
#  0.36876787653159493
# 第 14 次迭代的I_U为:
#  0.3688129469771733
# 第14次更新后的概率分布为:
#  [[0.42381309]
#  [0.57618691]]
# --------------------------------------------------
# 第 15 次迭代的q_j为:
#  [0.26004972 0.73995028]
# 第 15 次迭代的alpha_i为:
#  [[1.29121896 1.2912721 ]]
# 第 15 次迭代的u为:
#  [1.29124958]
# 第 15 次迭代的I_L为:
#  0.3687678773641515
# 第 15 次迭代的I_U为:
#  0.36879303697147137
# 第15次更新后的概率分布为:
#  [[0.42380304]
#  [0.57619696]]
# --------------------------------------------------
# 第 16 次迭代的q_j为:
#  [0.26004379 0.73995621]
# 第 16 次迭代的alpha_i为:
#  [[1.29123249 1.29126215]]
# 第 16 次迭代的u为:
#  [1.29124958]
# 第 16 次迭代的I_L为:
#  0.3687678776236039
# 第 16 次迭代的I_U为:
#  0.36878192250671776
# 第16次更新后的概率分布为:
#  [[0.42379743]
#  [0.57620257]]
# --------------------------------------------------
# 第 17 次迭代的q_j为:
#  [0.26004048 0.73995952]
# 第 17 次迭代的alpha_i为:
#  [[1.29124004 1.2912566 ]]
# 第 17 次迭代的u为:
#  [1.29124958]
# 第 17 次迭代的I_L为:
#  0.36876787770445735
# 第 17 次迭代的I_U为:
#  0.3687757180222034
# 第17次更新后的概率分布为:
#  [[0.4237943]
#  [0.5762057]]
# --------------------------------------------------
# 第 18 次迭代的q_j为:
#  [0.26003864 0.73996136]
# 第 18 次迭代的alpha_i为:
#  [[1.29124425 1.2912535 ]]
# 第 18 次迭代的u为:
#  [1.29124958]
# 第 18 次迭代的I_L为:
#  0.3687678777296531
# 第 18 次迭代的I_U为:
#  0.3687722544611461
# 第18次更新后的概率分布为:
#  [[0.42379255]
#  [0.57620745]]
# --------------------------------------------------
# 第 19 次迭代的q_j为:
#  [0.2600376 0.7399624]
# 第 19 次迭代的alpha_i为:
#  [[1.2912466  1.29125176]]
# 第 19 次迭代的u为:
#  [1.29124958]
# 第 19 次迭代的I_L为:
#  0.368767877737505
# 第 19 次迭代的I_U为:
#  0.3687703209798019
# 第19次更新后的概率分布为:
#  [[0.42379157]
#  [0.57620843]]
# --------------------------------------------------
# 第 20 次迭代的q_j为:
#  [0.26003703 0.73996297]
# 第 20 次迭代的alpha_i为:
#  [[1.29124792 1.2912508 ]]
# 第 20 次迭代的u为:
#  [1.29124958]
# 第 20 次迭代的I_L为:
#  0.36876787773995195
# 第 20 次迭代的I_U为:
#  0.3687692416426615
# 第20次更新后的概率分布为:
#  [[0.42379103]
#  [0.57620897]]
# --------------------------------------------------
# 第 21 次迭代的q_j为:
#  [0.26003671 0.73996329]
# 第 21 次迭代的alpha_i为:
#  [[1.29124865 1.29125026]]
# 第 21 次迭代的u为:
#  [1.29124958]
# 第 21 次迭代的I_L为:
#  0.3687678777407143
# 第 21 次迭代的I_U为:
#  0.3687686391187938
# 第21次更新后的概率分布为:
#  [[0.42379073]
#  [0.57620927]]
# --------------------------------------------------
# 第 22 次迭代的q_j为:
#  [0.26003653 0.73996347]
# 第 22 次迭代的alpha_i为:
#  [[1.29124906 1.29124996]]
# 第 22 次迭代的u为:
#  [1.29124958]
# 第 22 次迭代的I_L为:
#  0.3687678777409522
# 第 22 次迭代的I_U为:
#  0.36876830276882777
# 第22次更新后的概率分布为:
#  [[0.42379056]
#  [0.57620944]]
# --------------------------------------------------
# 第 23 次迭代的q_j为:
#  [0.26003643 0.73996357]
# 第 23 次迭代的alpha_i为:
#  [[1.29124929 1.29124979]]
# 第 23 次迭代的u为:
#  [1.29124958]
# 第 23 次迭代的I_L为:
#  0.36876787774102615
# 第 23 次迭代的I_U为:
#  0.3687681150064742
# 第23次更新后的概率分布为:
#  [[0.42379046]
#  [0.57620954]]
# --------------------------------------------------
# 第 24 次迭代的q_j为:
#  [0.26003637 0.73996363]
# 第 24 次迭代的alpha_i为:
#  [[1.29124942 1.2912497 ]]
# 第 24 次迭代的u为:
#  [1.29124958]
# 第 24 次迭代的I_L为:
#  0.36876787774104897
# 第 24 次迭代的I_U为:
#  0.3687680101909396
# 第24次更新后的概率分布为:
#  [[0.42379041]
#  [0.57620959]]
# --------------------------------------------------
# 第 25 次迭代的q_j为:
#  [0.26003634 0.73996366]
# 第 25 次迭代的alpha_i为:
#  [[1.29124949 1.29124964]]
# 第 25 次迭代的u为:
#  [1.29124958]
# 第 25 次迭代的I_L为:
#  0.3687678777410564
# 第 25 次迭代的I_U为:
#  0.36876795167923
# 输出信道容量的值为:
#   0.3687678777410564
# 达到容量时的输入概率为:
#   [[0.42379041]
#  [0.57620959]]
# --------------------------------------------------
# ****************************************************************************************************
# 初始化概率分布为:
#  [[0.5]
#  [0.5]]
# 第 1 次迭代的q_j为:
#  [0.425 0.15  0.425]
# 第 1 次迭代的alpha_i为:
#  [[1.49035558 1.49035558]]
# 第 1 次迭代的u为:
#  [1.49035558]
# 第 1 次迭代的I_L为:
#  0.5756565849372116
# 第 1 次迭代的I_U为:
#  0.5756565849372116
# 输出信道容量的值为:
#   0.5756565849372116
# 达到容量时的输入概率为:
#   [[0.5]
#  [0.5]]
# --------------------------------------------------
# ****************************************************************************************************
# 初始化概率分布为:
#  [[0.33333333]
#  [0.33333333]
#  [0.33333333]]
# 第 1 次迭代的q_j为:
#  [0.33166667 0.33666667 0.33166667]
# 第 1 次迭代的alpha_i为:
#  [[2.85044085 2.78954522 2.85044085]]
# 第 1 次迭代的u为:
#  [2.83014231]
# 第 1 次迭代的I_L为:
#  1.5008745987390466
# 第 1 次迭代的I_U为:
#  1.511185065434228
# 第1次更新后的概率分布为:
#  [[0.33572409]
#  [0.32855182]
#  [0.33572409]]
# --------------------------------------------------
# 第 2 次迭代的q_j为:
#  [0.33400961 0.33198078 0.33400961]
# 第 2 次迭代的alpha_i为:
#  [[2.8310422  2.82832385 2.8310422 ]]
# 第 2 次迭代的u为:
#  [2.83014908]
# 第 2 次迭代的I_L为:
#  1.5008780511181548
# 第 2 次迭代的I_U为:
#  1.5013332544127025
# 第2次更新后的概率分布为:
#  [[0.33583004]
#  [0.32833993]
#  [0.33583004]]
# --------------------------------------------------
# 第 3 次迭代的q_j为:
#  [0.33411343 0.33177313 0.33411343]
# 第 3 次迭代的alpha_i为:
#  [[2.83018895 2.83006756 2.83018895]]
# 第 3 次迭代的u为:
#  [2.8301491]
# 第 3 次迭代的I_L为:
#  1.5008780579658954
# 第 3 次迭代的I_U为:
#  1.5008983750180915
# 第3次更新后的概率分布为:
#  [[0.33583476]
#  [0.32833047]
#  [0.33583476]]
# --------------------------------------------------
# 第 4 次迭代的q_j为:
#  [0.33411807 0.33176386 0.33411807]
# 第 4 次迭代的alpha_i为:
#  [[2.83015088 2.83014545 2.83015088]]
# 第 4 次迭代的u为:
#  [2.8301491]
# 第 4 次迭代的I_L为:
#  1.5008780579795475
# 第 4 次迭代的I_U为:
#  1.5008789652301493
# 第4次更新后的概率分布为:
#  [[0.33583498]
#  [0.32833005]
#  [0.33583498]]
# --------------------------------------------------
# 第 5 次迭代的q_j为:
#  [0.33411828 0.33176345 0.33411828]
# 第 5 次迭代的alpha_i为:
#  [[2.83014918 2.83014893 2.83014918]]
# 第 5 次迭代的u为:
#  [2.8301491]
# 第 5 次迭代的I_L为:
#  1.5008780579795749
# 第 5 次迭代的I_U为:
#  1.5008780984934016
# 输出信道容量的值为:
#   1.5008780579795749
# 达到容量时的输入概率为:
#   [[0.33583498]
#  [0.32833005]
#  [0.33583498]]
# --------------------------------------------------
# ****************************************************************************************************

# %%
for k, v in ans_dict.items():
  print("概率转移矩阵的信道容量为：", k)
  print("达到容量的输入概率为：\n", np.transpose(v)[0])
  print("*" * 50)
# Out:
# 概率转移矩阵的信道容量为： 0.7858471834708413
# 达到容量的输入概率为：
#  [0.51288544 0.48711456]
# **************************************************
# 概率转移矩阵的信道容量为： 0.3687678777410564
# 达到容量的输入概率为：
#  [0.42379041 0.57620959]
# **************************************************
# 概率转移矩阵的信道容量为： 0.5756565849372116
# 达到容量的输入概率为：
#  [0.5 0.5]
# **************************************************
# 概率转移矩阵的信道容量为： 1.5008780579795749
# 达到容量的输入概率为：
#  [0.33583498 0.32833005 0.33583498]
# **************************************************
